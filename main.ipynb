# %% [markdown]
# ### Imports and version checks
# Load core libraries and confirm their versions for reproducibility.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import sklearn
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
)
# Out:
# 2.20.0
# 2.3.2
# 2.3.2
# 1.7.1

# %% [markdown]
# ## Reading Data

# %%
df = pd.read_csv("data/personality_datasert.csv")

# %% [markdown]
# #### Preview raw data
# Inspect the first few rows of the imported dataset to confirm structure and field names.

# %%
df.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %% [markdown]
#     - Time_spent_Alone: Hours spent alone daily (0–11).
#     - Stage_fear: Presence of stage fright (Yes/No).
#     - Social_event_attendance: Frequency of social events (0–10).
#     - Going_outside: Frequency of going outside (0–7).
#     - Drained_after_socializing: Feeling drained after socializing (Yes/No).
#     - Friends_circle_size: Number of close friends (0–15).
#     - Post_frequency: Social media post frequency (0–10).
#     - Personality: Target variable (Extrovert/Introvert).*

# %%
df = df.replace({
    "Yes": 1, "No": 0,
    "Introvert": 0, "Extrovert": 1
})
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14184\3952785252.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({

# %% [markdown]
# #### Check encoded values
# Verify that categorical replacements were applied correctly.

# %%
df.head()
# Out:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0           0                      4.0            6.0
# 1               9.0           1                      0.0            0.0
# 2               9.0           1                      1.0            2.0
# 3               0.0           0                      6.0            7.0
# 4               3.0           0                      9.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                          0                 13.0             5.0            1
# 1                          1                  0.0             3.0            0
# 2                          1                  5.0             2.0            0
# 3                          0                 14.0             8.0            1
# 4                          0                  8.0             5.0            1

# %% [markdown]
# #### Create train/validation split
# Hold out 20% of the data for validation to monitor generalization.

# %%
# 80% for training
train_df = df.sample(frac=0.8, random_state=42).copy()
# remaining 20% for validation and testing
val_df = df.drop(train_df.index).copy()

# %%
# scale feature columns to (0, 1) without touching the target
feature_cols = [col for col in train_df.columns if col != "Personality"]

max_val = train_df[feature_cols].max(axis=0)
min_val = train_df[feature_cols].min(axis=0)
value_range = (max_val - min_val).replace(0, 1e-9)  # guard against zero range

train_df[feature_cols] = (train_df[feature_cols] - min_val) / value_range
val_df[feature_cols] = (val_df[feature_cols] - min_val) / value_range

# %% [markdown]
# #### Normalize feature ranges
# Scale each feature to the 0–1 range using min–max normalization to stabilize training.

# %%
# now let's separate the targets and labels
X_train = train_df.drop('Personality',axis=1)
X_val = val_df.drop('Personality',axis=1)
y_train = train_df['Personality']
y_val = val_df['Personality']

# We'll need to pass the shape
# of features/inputs as an argument
# in our model, so let's define a variable 
# to save it.
input_shape = [X_train.shape[1]]

input_shape
# Out:
# [7]

# %% [markdown]
# #### Split features and labels
# Separate predictors from the target and record the model input shape.

# %% [markdown]
# ## creating a model

# %%
model = tf.keras.Sequential([

    tf.keras.layers.Dense(units=64, activation='relu',
                          input_shape=input_shape),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')  # sigmoid here
])
# Out:
# c:\Users\HP\OneDrive\سطح المكتب\projects\personality prediction\.venv\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,737 (18.50 KB)
#  Trainable params: 4,737 (18.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Inspect model architecture
# Summarize the Keras model to confirm layer shapes and parameter counts.

# %%
# adam optimizer works pretty well for
# all kinds of problems and is a good starting point
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',   # <-- correct loss for binary classification
    metrics=['accuracy']          # track accuracy too
)

# %% [markdown]
# #### Compile the model
# Configure optimizer, loss, and metrics for binary classification.

# %% [markdown]
# ## training the model

# %%
losses = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    # it will use 'batch_size' number
                   # of examples per example
    batch_size=32,    # smaller batch helps gradient updates for small dataset
    epochs=50         # more epochs to let the model learn patterns
)
# Out:
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8935 - loss: 0.4117 - val_accuracy: 0.9517 - val_loss: 0.2202
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2715 - val_accuracy: 0.9517 - val_loss: 0.2108
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2680 - val_accuracy: 0.9517 - val_loss: 0.2098
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2661 - val_accuracy: 0.9517 - val_loss: 0.2056
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2638 - val_accuracy: 0.9517 - val_loss: 0.2038
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2622 - val_accuracy: 0.9517 - val_loss: 0.2014
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2595 - val_accuracy: 0.9517 - val_loss: 0.2015
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2584 - val_accuracy: 0.9517 - val_loss: 0.1950
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2549 - val_accuracy: 0.9517 - val_loss: 0.2063
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2550 - val_accuracy: 0.9517 - val_loss: 0.1988
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2537 - val_accuracy: 0.9517 - val_loss: 0.1912
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2505 - val_accuracy: 0.9517 - val_loss: 0.1920
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2506 - val_accuracy: 0.9517 - val_loss: 0.1895
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9297 - loss: 0.2476 - val_accuracy: 0.9517 - val_loss: 0.1892
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2471 - val_accuracy: 0.9517 - val_loss: 0.1906
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2459 - val_accuracy: 0.9517 - val_loss: 0.1837
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2443 - val_accuracy: 0.9517 - val_loss: 0.1861
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2413 - val_accuracy: 0.9517 - val_loss: 0.1928
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2421 - val_accuracy: 0.9517 - val_loss: 0.1892
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9297 - loss: 0.2396 - val_accuracy: 0.9517 - val_loss: 0.1886
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9297 - loss: 0.2414 - val_accuracy: 0.9517 - val_loss: 0.1813
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2368 - val_accuracy: 0.9517 - val_loss: 0.1814
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2362 - val_accuracy: 0.9517 - val_loss: 0.1794
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2355 - val_accuracy: 0.9517 - val_loss: 0.1769
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2336 - val_accuracy: 0.9517 - val_loss: 0.1766
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2342 - val_accuracy: 0.9517 - val_loss: 0.1769
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2328 - val_accuracy: 0.9517 - val_loss: 0.1766
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2333 - val_accuracy: 0.9517 - val_loss: 0.1886
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2288 - val_accuracy: 0.9517 - val_loss: 0.1806
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2294 - val_accuracy: 0.9517 - val_loss: 0.1770
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2305 - val_accuracy: 0.9517 - val_loss: 0.1752
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2281 - val_accuracy: 0.9517 - val_loss: 0.1905
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2284 - val_accuracy: 0.9517 - val_loss: 0.1739
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2286 - val_accuracy: 0.9517 - val_loss: 0.1768
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2269 - val_accuracy: 0.9517 - val_loss: 0.1949
# Epoch 36/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2273 - val_accuracy: 0.9517 - val_loss: 0.1749
# Epoch 37/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2263 - val_accuracy: 0.9517 - val_loss: 0.1725
# Epoch 38/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2281 - val_accuracy: 0.9517 - val_loss: 0.1798
# Epoch 39/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2253 - val_accuracy: 0.9517 - val_loss: 0.1715
# Epoch 40/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2253 - val_accuracy: 0.9517 - val_loss: 0.1754
# Epoch 41/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2241 - val_accuracy: 0.9517 - val_loss: 0.1816
# Epoch 42/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2250 - val_accuracy: 0.9517 - val_loss: 0.1802
# Epoch 43/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2255 - val_accuracy: 0.9517 - val_loss: 0.1830
# Epoch 44/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2252 - val_accuracy: 0.9517 - val_loss: 0.1729
# Epoch 45/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2253 - val_accuracy: 0.9517 - val_loss: 0.1750
# Epoch 46/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2261 - val_accuracy: 0.9517 - val_loss: 0.1707
# Epoch 47/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9302 - loss: 0.2224 - val_accuracy: 0.9517 - val_loss: 0.1720
# Epoch 48/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2229 - val_accuracy: 0.9517 - val_loss: 0.1774
# Epoch 49/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2245 - val_accuracy: 0.9517 - val_loss: 0.1732
# Epoch 50/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2229 - val_accuracy: 0.9517 - val_loss: 0.1764

# %%
# Predict first three validation samples and return class labels
pred_samples = model.predict(X_val.iloc[0:3, :])
pred_classes = (pred_samples > 0.5).astype(int)
pred_classes
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# array([[0],
#        [1],
#        [0]])

# %% [markdown]
# #### Quick prediction sample
# Generate class labels for a few validation samples to sanity-check the trained model.

# %%
y_val.iloc[0:3]
# Out:
# 1     0
# 4     1
# 11    0
# Name: Personality, dtype: int64

# %% [markdown]
# #### Compare with true labels
# Review ground-truth labels for the sampled validation rows.

# %% [markdown]
# ## accuracy

# %%
predictions = model.predict(X_val)
pred_labels = (predictions > 0.5).astype(int)

# Compare with true labels
accuracy = np.mean(pred_labels.flatten() == y_val.values)

print("Validation Accuracy:", accuracy)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Validation Accuracy: 0.9517241379310345

# %% [markdown]
# #### Extended evaluation metrics
# Compute confusion matrix, precision, recall, F1, and ROC AUC on the validation split.

# %%
# Get final epoch accuracy
train_acc = losses.history['accuracy'][-1]
val_acc = losses.history['val_accuracy'][-1]

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Validation Accuracy: {val_acc:.4f}")

# Quick check
if train_acc > val_acc + 0.05:
    print("Warning: Possible overfitting")
elif train_acc < 0.6 and val_acc < 0.6:
    print("Warning: Possible underfitting")
else:
    print("Model seems well-fitted")
# Out:
# Final Training Accuracy: 0.9302
# Final Validation Accuracy: 0.9517
# Model seems well-fitted

# %%
# Confusion matrix and classification metrics
true_labels = y_val.values
probabilities = predictions.flatten()
pred_labels = pred_labels.flatten()

cm = confusion_matrix(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels)
recall = recall_score(true_labels, pred_labels)
f1 = f1_score(true_labels, pred_labels)
roc_auc = roc_auc_score(true_labels, probabilities)

print("Confusion matrix:\n", cm)
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1 score: {f1:.3f}")
print(f"ROC AUC: {roc_auc:.3f}")
print("\nClassification report:\n", classification_report(true_labels, pred_labels, target_names=["Introvert", "Extrovert"]))
# Out:
# Confusion matrix:
#  [[251  11]
#  [ 17 301]]
# Precision: 0.965
# Recall: 0.947
# F1 score: 0.956
# ROC AUC: 0.974
#
# Classification report:
#                precision    recall  f1-score   support
#
#    Introvert       0.94      0.96      0.95       262
#    Extrovert       0.96      0.95      0.96       318
#
#     accuracy                           0.95       580
#    macro avg       0.95      0.95      0.95       580
# weighted avg       0.95      0.95      0.95       580
